# %% [markdown]
# ## Introduction
# In this notebook we show how to use the modal interpolant construction to build a straight-line flow the connects univariate Gaussians.

# %%
import jax
import jax.numpy as jnp
import matplotlib.pyplot as plt
from scipy.stats import gaussian_kde
import optimalinterp as oi

jax.config.update("jax_enable_x64", True)
jax.config.update("jax_debug_nans", True)

# %% [markdown]
# ## 1. Problem Setup
# We start by building the problem. The core object here is the "StochasticBasis" which defined the family $(Z_\alpha)_{\alpha=1}^N$ of random variables that interpolates between the source and target measures.
# Namely, by construction we have
# $$ Z_0 \overset{d}{=} X_0 \quad Z_N \overset{d}{=} X_1 $$
# where $X_0 \sim \mu$ and $X_1 \sim \nu$ are the source and target measures respectively.
#
# In this example we work in $d=1$ dimensions and take the source to be a standard normal and the target to be a Gaussian with some mean and covariance.

# %%
# Generate samples to plot the source and target distributions
n_samples = 1000

key = jax.random.PRNGKey(0)
stochastic_basis = oi.GaussianConvolutionBasis(
    N_modes=4,
    mean=2.0,
    std_dev=4.0,
)
samples = stochastic_basis.sample(N_samples=1000, key=key)
source_samples = samples[:, 0]
target_samples = samples[:, -1]

# Plot samples with KDE on the same plot

fig, ax = plt.subplots(figsize=(10, 6))

# Source distribution
ax.hist(
    source_samples,
    bins=50,
    density=True,
    alpha=0.5,
    color="blue",
    edgecolor="black",
    label="Source Samples",
)
kde_source = gaussian_kde(source_samples)
x_range = jnp.linspace(-10, 15, 200)
ax.plot(x_range, kde_source(x_range), color="blue", linewidth=2, label="Source KDE")

# Target distribution
ax.hist(
    target_samples,
    bins=50,
    density=True,
    alpha=0.5,
    color="red",
    edgecolor="black",
    label="Target Samples",
)
kde_target = gaussian_kde(target_samples)
ax.plot(x_range, kde_target(x_range), color="red", linewidth=2, label="Target KDE")

ax.set_title("Source and Target Distribution Samples")
ax.set_xlabel("x")
ax.set_ylabel("Density")
ax.set_xlim(-10, 15)
ax.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# Now we proceed by building an optimal interpolant object.
# Note that upon instantiation, one *will not* be able to call the interpolant, as the
# coefficients $t \mapsto \psi(t)$ have not yet been computed.
#
# However, before we build an optimal interpolant we build a *standard stochastic interpolant*
# to give ourselves a point of comparison. That is, we instantiate the stochastic interpolant
# $$ X_t = (1 - t) X_0 + t X_1 $$

# %%
simple_stochastic_basis = oi.GaussianConvolutionBasis(
    N_modes=2,
    mean=10.0,
    std_dev=2.0,
)

simple_psi = jnp.array(
    [
        jnp.linspace(1, 0, 100),
        jnp.linspace(0, 1, 100),
    ]
).T

standard_interpolant = oi.modal_interpolant_factory(
    "time interpolated",
    t=jnp.linspace(0, 1, 100),  # 100 time points
    Z=simple_stochastic_basis,
    psi=simple_psi,
    psi_dot=jnp.ones((100,2))
)

# Plot sample paths of the standard interpolant
n_paths = 50
t_eval = jnp.linspace(0, 1, 100)
key = jax.random.PRNGKey(0)

# Shape: (n_paths, n_times)
sample_paths = standard_interpolant(key, n_paths)

fig, ax = plt.subplots(figsize=(10, 6))
t_vals = standard_interpolant.default_tgrid()

for i in range(n_paths):
    ax.plot(t_vals, sample_paths[i, :], alpha=0.5, linewidth=1)

ax.set_title("Standard Interpolant Sample Paths")
ax.set_xlabel("Time t")
ax.set_ylabel("x")
ax.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 2. Compute Optimal Coefficients
# Next, we compute the optimal coefficients $t \mapsto \psi(t)$ for the optimal interpolant.
# This is done by calling the `compute_optimal_psi` method.

# %%
N_test = 2*stochastic_basis.N_modes # Choose number of test functions as 2 x N_modes
optimal_interpolant = oi.optimal_interpolant.compute_optimal_psi_shooting(
    stochastic_basis, allow_failure=True, N_test=N_test,
    max_optimizer_steps=1000, rtol=1e-12, atol=1e-12
)
# Out:
# Step: 0, Accepted steps: 0, Steps since acceptance: 0, Loss on this step: 1.0, Loss on the last accepted step: 0.0, Step size: 1.0, y: [0. 0. 0. 0.], y on the last accepted step: [0. 0. 0. 0.]
# Step: 1, Accepted steps: 1, Steps since acceptance: 0, Loss on this step: inf, Loss on the last accepted step: 1.0, Step size: 0.25, y: [-0.5  0.   0.   0.5], y on the last accepted step: [0. 0. 0. 0.]
# Step: 2, Accepted steps: 1, Steps since acceptance: 1, Loss on this step: 0.5358583215633681, Loss on the last accepted step: 1.0, Step size: 0.875, y: [-0.2  0.   0.   0.2], y on the last accepted step: [-0.2  0.   0.   0.2]
# Step: 3, Accepted steps: 2, Steps since acceptance: 0, Loss on this step: inf, Loss on the last accepted step: 0.535858321563368, Step size: 0.21875, y: [-0.36064477 -0.05210226 -0.10734059  0.57769191], y on the last accepted step: [-0.2  0.   0.   0.2]
# Step: 4, Accepted steps: 2, Steps since acceptance: 1, Loss on this step: 0.2542321520385627, Loss on the last accepted step: 0.535858321563368, Step size: 0.21875, y: [-0.29400485 -0.02351857 -0.04013675  0.39924217], y on the last accepted step: [-0.29400485 -0.02351857 -0.04013675  0.39924217]
# Step: 5, Accepted steps: 3, Steps since acceptance: 0, Loss on this step: 0.22473641935576902, Loss on the last accepted step: 0.2542321520385627, Step size: 0.21875, y: [-0.32730091 -0.06401168 -0.09167533  0.38488346], y on the last accepted step: [-0.32730091 -0.06401168 -0.09167533  0.38488346]
# Step: 6, Accepted steps: 4, Steps since acceptance: 0, Loss on this step: 0.20830154165068746, Loss on the last accepted step: 0.22473641935576905, Step size: 0.765625, y: [-0.35164148 -0.09432931 -0.13164603  0.39025063], y on the last accepted step: [-0.35164148 -0.09432931 -0.13164603  0.39025063]
# Step: 7, Accepted steps: 5, Steps since acceptance: 0, Loss on this step: 0.18805768935284234, Loss on the last accepted step: 0.20830154165068746, Step size: 2.6796875, y: [-0.37677928 -0.14895291 -0.21033156  0.4106046 ], y on the last accepted step: [-0.37677928 -0.14895291 -0.21033156  0.4106046 ]
# Step: 8, Accepted steps: 6, Steps since acceptance: 0, Loss on this step: 0.1714386351210484, Loss on the last accepted step: 0.1880576893528423, Step size: 9.37890625, y: [-0.29809543 -0.20593369 -0.33474221  0.47681286], y on the last accepted step: [-0.29809543 -0.20593369 -0.33474221  0.47681286]
# Step: 9, Accepted steps: 7, Steps since acceptance: 0, Loss on this step: 0.15394002899925366, Loss on the last accepted step: 0.1714386351210484, Step size: 9.37890625, y: [-0.03826467 -0.25677628 -0.54857233  0.60011626], y on the last accepted step: [-0.03826467 -0.25677628 -0.54857233  0.60011626]
# Step: 10, Accepted steps: 8, Steps since acceptance: 0, Loss on this step: 0.14990599945198635, Loss on the last accepted step: 0.1539400289992537, Step size: 9.37890625, y: [ 0.06951399 -0.25494014 -0.65535071  0.65756946], y on the last accepted step: [ 0.06951399 -0.25494014 -0.65535071  0.65756946]
# Step: 11, Accepted steps: 9, Steps since acceptance: 0, Loss on this step: 0.1490313096479322, Loss on the last accepted step: 0.14990599945198635, Step size: 9.37890625, y: [ 0.13189763 -0.25431644 -0.70572703  0.69122139], y on the last accepted step: [ 0.13189763 -0.25431644 -0.70572703  0.69122139]
# Step: 12, Accepted steps: 10, Steps since acceptance: 0, Loss on this step: 0.14884112849292702, Loss on the last accepted step: 0.1490313096479322, Step size: 9.37890625, y: [ 0.15711995 -0.25347203 -0.72909013  0.70320987], y on the last accepted step: [ 0.15711995 -0.25347203 -0.72909013  0.70320987]
# Step: 13, Accepted steps: 11, Steps since acceptance: 0, Loss on this step: 0.14879387881526662, Loss on the last accepted step: 0.14884112849292702, Step size: 9.37890625, y: [ 0.17303817 -0.25443436 -0.74025475  0.71190267], y on the last accepted step: [ 0.17303817 -0.25443436 -0.74025475  0.71190267]
# Step: 14, Accepted steps: 12, Steps since acceptance: 0, Loss on this step: 0.14878126854269744, Loss on the last accepted step: 0.14879387881526657, Step size: 9.37890625, y: [ 0.17886407 -0.25430003 -0.74594156  0.71433661], y on the last accepted step: [ 0.17886407 -0.25430003 -0.74594156  0.71433661]
# Step: 15, Accepted steps: 13, Steps since acceptance: 0, Loss on this step: 0.14877767187168003, Loss on the last accepted step: 0.14878126854269744, Step size: 9.37890625, y: [ 0.18318575 -0.25475761 -0.74861731  0.71681638], y on the last accepted step: [ 0.18318575 -0.25475761 -0.74861731  0.71681638]
# Step: 16, Accepted steps: 14, Steps since acceptance: 0, Loss on this step: 0.14877654144715172, Loss on the last accepted step: 0.14877767187168003, Step size: 9.37890625, y: [ 0.18443816 -0.25465865 -0.7500745   0.71721673], y on the last accepted step: [ 0.18443816 -0.25465865 -0.7500745   0.71721673]
# Step: 17, Accepted steps: 15, Steps since acceptance: 0, Loss on this step: 0.148776164373037, Loss on the last accepted step: 0.14877654144715172, Step size: 9.37890625, y: [ 0.18567987 -0.25483679 -0.75072424  0.71798264], y on the last accepted step: [ 0.18567987 -0.25483679 -0.75072424  0.71798264]
# Step: 18, Accepted steps: 16, Steps since acceptance: 0, Loss on this step: 0.14877602509170593, Loss on the last accepted step: 0.14877616437303703, Step size: 9.37890625, y: [ 0.18589754 -0.2547752  -0.75110717  0.71799055], y on the last accepted step: [ 0.18589754 -0.2547752  -0.75110717  0.71799055]
# Step: 19, Accepted steps: 17, Steps since acceptance: 0, Loss on this step: 0.14877597121985428, Loss on the last accepted step: 0.14877602509170593, Step size: 9.37890625, y: [ 0.18627887 -0.25484581 -0.7512618   0.71824681], y on the last accepted step: [ 0.18627887 -0.25484581 -0.7512618   0.71824681]
# Step: 20, Accepted steps: 18, Steps since acceptance: 0, Loss on this step: 0.14877594896986016, Loss on the last accepted step: 0.14877597121985428, Step size: 9.37890625, y: [ 0.18628932 -0.25481345 -0.75136518  0.71820717], y on the last accepted step: [ 0.18628932 -0.25481345 -0.75136518  0.71820717]
# Step: 21, Accepted steps: 19, Steps since acceptance: 0, Loss on this step: 0.14877593958182908, Loss on the last accepted step: 0.14877594896986016, Step size: 9.37890625, y: [ 0.18641581 -0.25484257 -0.75140006  0.71829991], y on the last accepted step: [ 0.18641581 -0.25484257 -0.75140006  0.71829991]
# Step: 22, Accepted steps: 20, Steps since acceptance: 0, Loss on this step: 0.14877593550041324, Loss on the last accepted step: 0.14877593958182908, Step size: 9.37890625, y: [ 0.18639845 -0.25482687 -0.75142909  0.71827126], y on the last accepted step: [ 0.18639845 -0.25482687 -0.75142909  0.71827126]
# Step: 23, Accepted steps: 21, Steps since acceptance: 0, Loss on this step: 0.148775933713918, Loss on the last accepted step: 0.14877593550041324, Step size: 9.37890625, y: [ 0.18644385 -0.25483926 -0.75143602  0.71830718], y on the last accepted step: [ 0.18644385 -0.25483926 -0.75143602  0.71830718]
# Step: 24, Accepted steps: 22, Steps since acceptance: 0, Loss on this step: 0.14877593292271102, Loss on the last accepted step: 0.148775933713918, Step size: 9.37890625, y: [ 0.18643051 -0.25483193 -0.75144463  0.71829161], y on the last accepted step: [ 0.18643051 -0.25483193 -0.75144463  0.71829161]
# Step: 25, Accepted steps: 23, Steps since acceptance: 0, Loss on this step: 0.14877593257174138, Loss on the last accepted step: 0.14877593292271102, Step size: 9.37890625, y: [ 0.18644798 -0.25483731 -0.75144554  0.71830626], y on the last accepted step: [ 0.18644798 -0.25483731 -0.75144554  0.71830626]
# Step: 26, Accepted steps: 24, Steps since acceptance: 0, Loss on this step: 0.14877593241536344, Loss on the last accepted step: 0.14877593257174138, Step size: 9.37890625, y: [ 0.18644061 -0.25483395 -0.75144828  0.71829861], y on the last accepted step: [ 0.18644061 -0.25483395 -0.75144828  0.71829861]
# Step: 27, Accepted steps: 25, Steps since acceptance: 0, Loss on this step: 0.14877593234567704, Loss on the last accepted step: 0.14877593241536344, Step size: 9.37890625, y: [ 0.1864477  -0.25483632 -0.75144813  0.7183048 ], y on the last accepted step: [ 0.1864477  -0.25483632 -0.75144813  0.7183048 ]
# Step: 28, Accepted steps: 26, Steps since acceptance: 0, Loss on this step: 0.14877593231457104, Loss on the last accepted step: 0.14877593234567704, Step size: 9.37890625, y: [ 0.18644405 -0.2548348  -0.75144908  0.7183012 ], y on the last accepted step: [ 0.18644405 -0.2548348  -0.75144908  0.7183012 ]
# Step: 29, Accepted steps: 27, Steps since acceptance: 0, Loss on this step: 0.148775932300687, Loss on the last accepted step: 0.14877593231457104, Step size: 9.37890625, y: [ 0.18644704 -0.25483584 -0.75144887  0.71830388], y on the last accepted step: [ 0.18644704 -0.25483584 -0.75144887  0.71830388]
# Step: 30, Accepted steps: 28, Steps since acceptance: 0, Loss on this step: 0.14877593229448488, Loss on the last accepted step: 0.148775932300687, Step size: 9.37890625, y: [ 0.18644532 -0.25483516 -0.75144923  0.71830222], y on the last accepted step: [ 0.18644532 -0.25483516 -0.75144923  0.71830222]
# Step: 31, Accepted steps: 29, Steps since acceptance: 0, Loss on this step: 0.1487759322917173, Loss on the last accepted step: 0.1487759322944849, Step size: 9.37890625, y: [ 0.18644661 -0.25483562 -0.7514491   0.7183034 ], y on the last accepted step: [ 0.18644661 -0.25483562 -0.7514491   0.7183034 ]
# Step: 32, Accepted steps: 30, Steps since acceptance: 0, Loss on this step: 0.14877593229048025, Loss on the last accepted step: 0.14877593229171726, Step size: 9.37890625, y: [ 0.18644581 -0.25483532 -0.75144924  0.71830265], y on the last accepted step: [ 0.18644581 -0.25483532 -0.75144924  0.71830265]
# Step: 33, Accepted steps: 31, Steps since acceptance: 0, Loss on this step: 0.148775932289928, Loss on the last accepted step: 0.14877593229048025, Step size: 9.37890625, y: [ 0.18644638 -0.25483552 -0.75144917  0.71830317], y on the last accepted step: [ 0.18644638 -0.25483552 -0.75144917  0.71830317]
# Step: 34, Accepted steps: 32, Steps since acceptance: 0, Loss on this step: 0.14877593228968145, Loss on the last accepted step: 0.148775932289928, Step size: 9.37890625, y: [ 0.18644602 -0.25483539 -0.75144923  0.71830283], y on the last accepted step: [ 0.18644602 -0.25483539 -0.75144923  0.71830283]
# Step: 35, Accepted steps: 33, Steps since acceptance: 0, Loss on this step: 0.14877593228957176, Loss on the last accepted step: 0.14877593228968145, Step size: 9.37890625, y: [ 0.18644627 -0.25483548 -0.7514492   0.71830306], y on the last accepted step: [ 0.18644627 -0.25483548 -0.7514492   0.71830306]
# Step: 36, Accepted steps: 34, Steps since acceptance: 0, Loss on this step: 0.14877593228952124, Loss on the last accepted step: 0.14877593228957176, Step size: 9.37890625, y: [ 0.18644611 -0.25483542 -0.75144922  0.71830291], y on the last accepted step: [ 0.18644611 -0.25483542 -0.75144922  0.71830291]
# Step: 37, Accepted steps: 35, Steps since acceptance: 0, Loss on this step: 0.1487759322895004, Loss on the last accepted step: 0.1487759322895212, Step size: 9.37890625, y: [ 0.18644622 -0.25483546 -0.75144921  0.71830301], y on the last accepted step: [ 0.18644622 -0.25483546 -0.75144921  0.71830301]
# Step: 38, Accepted steps: 36, Steps since acceptance: 0, Loss on this step: 0.1487759322894905, Loss on the last accepted step: 0.1487759322895004, Step size: 9.37890625, y: [ 0.18644614 -0.25483543 -0.75144922  0.71830294], y on the last accepted step: [ 0.18644614 -0.25483543 -0.75144922  0.71830294]
# Step: 39, Accepted steps: 37, Steps since acceptance: 0, Loss on this step: 0.1487759322894838, Loss on the last accepted step: 0.14877593228949046, Step size: 9.37890625, y: [ 0.18644619 -0.25483545 -0.75144921  0.71830299], y on the last accepted step: [ 0.18644619 -0.25483545 -0.75144921  0.71830299]
# Step: 40, Accepted steps: 38, Steps since acceptance: 0, Loss on this step: 0.14877593228948224, Loss on the last accepted step: 0.14877593228948377, Step size: 9.37890625, y: [ 0.18644616 -0.25483544 -0.75144922  0.71830296], y on the last accepted step: [ 0.18644616 -0.25483544 -0.75144922  0.71830296]
# Step: 41, Accepted steps: 39, Steps since acceptance: 0, Loss on this step: 0.14877593228948224, Loss on the last accepted step: 0.14877593228948224, Step size: 2.3447265625, y: [ 0.18644618 -0.25483545 -0.75144921  0.71830298], y on the last accepted step: [ 0.18644616 -0.25483544 -0.75144922  0.71830296]
# Step: 42, Accepted steps: 39, Steps since acceptance: 1, Loss on this step: 0.14877593228948127, Loss on the last accepted step: 0.14877593228948224, Step size: 2.3447265625, y: [ 0.18644617 -0.25483544 -0.75144921  0.71830297], y on the last accepted step: [ 0.18644617 -0.25483544 -0.75144921  0.71830297]
# Step: 43, Accepted steps: 40, Steps since acceptance: 0, Loss on this step: 0.14877593228948272, Loss on the last accepted step: 0.14877593228948127, Step size: 0.586181640625, y: [ 0.18644617 -0.25483544 -0.75144921  0.71830296], y on the last accepted step: [ 0.18644617 -0.25483544 -0.75144921  0.71830297]
# Step: 44, Accepted steps: 40, Steps since acceptance: 1, Loss on this step: 0.14877593228948108, Loss on the last accepted step: 0.14877593228948127, Step size: 0.586181640625, y: [ 0.18644617 -0.25483544 -0.75144921  0.71830296], y on the last accepted step: [ 0.18644617 -0.25483544 -0.75144921  0.71830296]
# Step: 45, Accepted steps: 41, Steps since acceptance: 0, Loss on this step: 0.14877593228948063, Loss on the last accepted step: 0.14877593228948108, Step size: 2.0516357421875, y: [ 0.18644617 -0.25483544 -0.75144921  0.71830297], y on the last accepted step: [ 0.18644617 -0.25483544 -0.75144921  0.71830297]
# Step: 46, Accepted steps: 42, Steps since acceptance: 0, Loss on this step: 0.14877593228948052, Loss on the last accepted step: 0.1487759322894806, Step size: 7.18072509765625, y: [ 0.18644617 -0.25483544 -0.75144921  0.71830297], y on the last accepted step: [ 0.18644617 -0.25483544 -0.75144921  0.71830297]
# optimistix._solution.RESULTS<>,
# 0.47415902871452087

# %% [markdown]
# ## 3. Visualize Sample Paths and mean velocity.
# We start by plotting the sample paths of the optimal interpolant.

# %%
n_paths = 50
t_eval = jnp.linspace(0, 1, 103)
key = jax.random.PRNGKey(0)
sample_paths = optimal_interpolant(
    N_samples=n_paths, key=key, t_eval=t_eval
)  # Shape: (n_paths, n_times)

fig, ax = plt.subplots(figsize=(10, 6))
for i in range(n_paths):
    ax.plot(t_eval, sample_paths[i, :], alpha=0.5, linewidth=1)

ax.set_title("Optimal Interpolant Sample Paths")
ax.set_xlabel("Time t")
ax.set_ylabel("x")
ax.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# Finally, we can compute and visualize the mean velocity field induced by the optimal interpolant.
# We use the `interpolate_velocity_field` utility function for this purpose.

# %%
key = jax.random.PRNGKey(42)
x_grid = jnp.linspace(-10, 10, 101)
oi.visualization.visualize_interpolant_flow(
    optimal_interpolant,
    key,
    x_grid,
    bin_width=0.2,
    kernel_type="gaussian",
    N_velocity_samples=15000,
    N_flow_samples=50,
)
